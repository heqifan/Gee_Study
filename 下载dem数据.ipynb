# %%
import geemap
import ee

Map = geemap.Map(center=(29, 85))
Map
# Out:
# Map(center=[29, 85], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Tog…

# %%
roi = Map.draw_last_feature.geometry()

# %%
dem_img = ee.Image("USGS/SRTMGL1_003").clip(roi)
Map.addLayer(dem_img, {'min':0, 'max':2000}, 'eleva')

# %%
def clip_dow_merge(geo: ee.Geometry, image: ee.Image, outfile: str, scale: int,
                   crs='epsg:4326', sep=0.25):
    """

    Args:
        geo: ee.Geometry, 需要下载的区域矢量几何
        image: ee.Image, 需要下载的影像
        outfile: str, 输出文件路径和名称，不需要文件后缀，下载的影响默认后缀为tif
        scale: int, 下载时的像元大小
        crs: str, 下载影像的投影，默认为 'epsg:4326' wgs1984投影
        sep: float, 单波段10m分辨率像元的影像裁剪大小(单位：经纬度)，默认为0.25
    Returns: None

    """
    import os
    import numpy as np
    import rasterio
    from glob import glob
    from rasterio.merge import merge
    import shutil
    import geemap
    import math
    bounds = geo.bounds()
    bands = image.bandNames().size().getInfo()
    poy = np.array(bounds.coordinates().getInfo()[0])
    min_x = poy[:, 0].min()
    max_x = poy[:, 0].max()
    min_y = poy[:, 1].min()
    max_y = poy[:, 1].max()
    step = scale / 10 * sep / (int(math.sqrt(bands))+1)
    end_x = int((max_x - min_x) / step) + 1
    end_y = int((max_y - min_y) / step) + 1
    polys = []
    for i in range(end_y):
        y1 = min_y + step * i
        y2 = min_y + step * (i + 1)
        if y2 > max_y:
            y2 = max_y
        for j in range(end_x):
            x1 = min_x + step * j
            x2 = min_x + step * (j + 1)
            if x2 > max_x:
                x2 = max_x
            poly = ee.Geometry(ee.Geometry.Rectangle([float(x1), float(y1), float(x2), float(y2)]), None, False)
            polys.append(poly)
    if len(polys) > 1:
        print(f"分割成{len(polys)}份, 开始下载:")
        path = outfile+'_mk'
        t = 1
        if not os.path.exists(path):
            t = 0
            os.makedirs(path)
        for j, i in enumerate(polys):
            if not os.path.exists(path+f'/temp_{j}.tif'):
                if t:
                    clip_dow_merge(i, image, path + f'/temp_{j}', scale, sep=sep*0.5)
                else:
                    geemap.ee_export_image(image, path + f'/temp_{j}.tif', scale=scale, crs=crs, region=i)
            else:
                continue
        files = glob(path+"/*.tif")
        if len(files) == len(polys):
            src_files_to_mosaic = []
            for tif_f in files:
                src = rasterio.open(tif_f)
                src_files_to_mosaic.append(src)
            mosaic, out_trans = merge(src_files_to_mosaic)
            out_meta = src.meta.copy()
            out_meta.update({"driver": "GTiff",
                             "height": mosaic.shape[1],
                             "width": mosaic.shape[2],
                             "transform": out_trans,
                             })
            with rasterio.open(outfile+".tif", "w", **out_meta) as dest:
                dest.write(mosaic)
            for src in src_files_to_mosaic:
                src.close()
            shutil.rmtree(path)
        else:
            print('下载不完全！！')
    else:
        geemap.ee_export_image(image, outfile+'.tif', scale=scale, crs=crs, region=geo)
    print("download successful !!!")

# %%
import os
out_name = r'C:\Users\树风\Desktop\下载数据/JX_DEM_90m'
while not os.path.exists(out_name+'.tif'):
    clip_dow_merge(roi, dem_img.clip(roi), out_name, 90)
# Out:
# 分割成36份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8ef16ad4bcc06cfd0f9b068de088bead-da7e5bd69b8f9c767103b5086ebe890b:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0596fd690d8dc3d5f72b6a4f7531a87b-e21a73e25cd7a1737efc4d28d85595c7:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9fa280155761ea3fd6ca3080995aa6df-e0b38b52417d929bfd6916ede04d0470:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5b21923894136bfc2ba3000057df2d28-73b179443f92e78f84217e88b2841086:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cf25d307b009ad0d00609781f75090a1-51676903ba52536fad7752a6241eb930:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/cf25d307b009ad0d00609781f75090a1-51676903ba52536fad7752a6241eb930:getPixels (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1945cc6542fb99a76277c1e2782dd8e8-626730bb25a84f0914f01324c6208240:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ff5a242430946de41d279f1f843cb0e2-39f684eb5cfb1720805662631a612a6e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b584406c50c6e609e2b1a43b63105b32-6e2284358558161dbc865e310f9af35e:getPixels
# Please wait ...
# File is not a zip file
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6206d18423a4a2a9e21cc4b9c8bc9216-592d70cc6964f3ff779eb6805cb7775e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_8.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/61c64f39e30c4612252608b926357d3d-b788eb9ca1f5b30813def11b6a1ee9a5:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_9.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9f5544d2de93cceb86d4cd4257ec4c23-f02b9ca86d7f3d7c08f870074f21643b:getPixels
# Please wait ...
# File is not a zip file
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dd0cb54f0a82d89926e2ca5be8c74488-20158e9a4ab0b6871f0514f04694e4ea:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/48b177b77977932e6ec541712b81f310-d7a96e068ee0778701a451a4fc8a6f96:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/e521d4a261e3b003c518355cdc0a2974-f87b5a7548dc93818555b02e8ff88634:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_13.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7917e101a741ff6db53aabb5fbe7a89a-1d4a97e3641f8dd5f95e24e82fa160fb:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/7917e101a741ff6db53aabb5fbe7a89a-1d4a97e3641f8dd5f95e24e82fa160fb:getPixels (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_BAD_RECORD_MAC] sslv3 alert bad record mac (_ssl.c:2633)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7397efd2d5ea805fbaa71bb9e2d8fa00-29dc1879e9854cd3211a9c75c326271e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3b16f3f295cce8447c84277717282ab7-b439510dbaced0425c7fcf824e071991:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/3b16f3f295cce8447c84277717282ab7-b439510dbaced0425c7fcf824e071991:getPixels (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/752768024736b6c55e6112d407a9d6fc-963625926697757f88bd6e59be4ba740:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_17.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/48ac433c94f96dc9c5c8c111d5f5758f-8faf5586e28ef02aee308b85180ac0d5:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/fda41896f96dfdf5a245803ac4b56ae7-5ef0182c59364774a5ba0e8564137777:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6eb0208f1332316b25b6920af0ddc8a7-57f736cf456e10d2232c012c44667966:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/33ae01bc744a991687a9ffee3bf7bcf5-418ade12443259a49410fd6968c5fb22:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a2f15041c2b99803018ed5219a7c6a0f-cf0d35bf49fc8c69ed0ce61a8d50eb9c:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/13570bf114f6ad3548642cbce5860d69-0adc584105165ab8eda8e567d90ff1b3:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f8373607fd7d51e518b4044209da32b2-4be28db2f03920d19950fade0dc00f67:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_24.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/92277b39dac422b16f45b97b31d6a3dd-2525c04068cfb31929427d5e283e4935:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c58ffc7f6b6b12e10c2d4e460273199a-0a2738106d09ca834d9573844069ce1d:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/624b1e26c41c08675654208573caacac-d199e441e76dc778c68dfed9d3938cda:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b4341fab3cb86fb97613f8931d01cc45-d19f2a4b744be4963fa5142c103f27f4:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_28.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5b82a652021674b10dcc425f6e6c1da0-2dc3c27a62eb1c23f383b6feeba1b24d:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_29.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/663e4cc012da384c0e25b3481db9f836-fbe4ec03268e9de14132d4e6749d893c:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_30.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b95a31640d7347567f19d64bc5ca6203-6b3772f9201fa27eeafd587969ce5272:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8e82c897144d844ada03116f274b72f3-cc02f0722be1812d2f219613f5474f65:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_32.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/414a403f912c2fb60735741c27808ff2-a57a8b43c1b0e2ce35751c3a3f8ea12a:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/414a403f912c2fb60735741c27808ff2-a57a8b43c1b0e2ce35751c3a3f8ea12a:getPixels (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d9336ace0bff2c694203a2d5347c7f4e-f941e0ffc9948f1a8e3937bf3b1b781c:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_34.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/359abb9d111c564b82ea0556aedae095-bc2a583de0607d723011ab4eb27f51f8:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_35.tif
# 下载不完全！！
# download successful !!!
# 分割成36份, 开始下载:
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/02c863370738d8a73b6e7972257f54bd-45a4e064ead898d768e05bc4f9f81129:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2ea1194e116f2cc0d174fa032d2bfda8-00dbf99bb9424bec8c32cbead9d51580:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/bfcab188ed3a5ee42b900a82a070d958-d0e260e65cfc64998406ffe0eaa1f23e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3498505d620a376c72f1e6ecde2c05f6-6f96bf8093ba888689d225ffac76cd9b:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/37238f0de09ca25448ba6b695935fbdf-e6edc9c1308542ad6597441e19631d90:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9b53fa6bfa25cb08177014de964fbe4f-0faad75fffb0ae4993a69162ce36c60a:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/561ae03e64f12a335996378fa01349d5-8aa12e4977963b426f8f91dd901079cc:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a674847e4580ebfed735f4c835954dbd-5068ea72aa3431e67646bd73bad54e52:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ed518f91ca94b423bff484c93dda2fa8-de971b077d7c1f18a5be2b168bbb9034:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_4_mk\temp_8.tif
# download successful !!!
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/65e80e0aff44ba66ee87971882de8508-9f247eeeb1c900dd413ca9ca52cc774e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a468b9d3993735877d274035be291060-82660ea36ba257938f5b76e7c5a697cf:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d17495115fe62e97f646f12556e20d27-10240bd817d70f29aa825e638948e003:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/23cbbe4f03df7e365787b532914bd738-6e155e3e219442335e963a5e1f98dbe8:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dafc2ea974371939da674ea900cb978a-df47fc11e451e7c6c149b55c8be33fec:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/42ea10a29ab6246b718fac4c771a3df4-97f9cf4b8b569ffbc0c9ad65ee83e293:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6b915ec9e5e83ada5cf2979e633acd3e-02f89974606d58c583089114b5d8bafc:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/baa22e69dd4af478fc88251eff03b3f5-196b73b8816fcd36f6855c6bd7cc6655:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cf0e37de1052d2dd4bf9ce2adc5c063a-7878a6f10e12b2ed3c758705fe40c3d0:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_7_mk\temp_8.tif
# download successful !!!
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/da9c9117f8c269244076532ef5971793-0986e03f79a4c65924a644777ebf514e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7094bfc7ba95987528688637d598fc05-b57df7adeb6de2e7f82fc69d565d2a30:getPixels
# Please wait ...
# File is not a zip file
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7f2c62e611700d6bee0ab814526026b7-3a5934df1e77c3234ed85bfa0aa6cfee:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/559aaa18c1a3379380f23534cfa537f3-e8e686735ca2bc7588322319be385d20:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a33b5c6aca9300e407be626fab0e7f44-e68a4ca53b0482e68243ac9419218795:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5b52fb37f4e4cef73c1365b22c811f98-9146470c792279ada7d8066b3f217f07:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/ba71cf3883419b883c1159bb85836515-15f619cd2e4cfb5aeb09cc85b3d43be7:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f4a8761b885188d24bb2e8c9a97abe7c-acdca7013916fdbae40fb819b57590b8:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0a5f7d6678dff6f94ef3f1da1583b744-85c5537eedbf9a9b50f1b1e748156987:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_8.tif
# 下载不完全！！
# download successful !!!
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7fd35b0698f3fed8dbdab0a8866fdd9c-547831beeb3adad3f0b7557fa6a69dfa:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/1595a323c0fa4ddc9dea6690a2a2ac24-20d8a83aa090383eec3712c1b66df8e4:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4c31a9795a733c51d07660af925e014f-1cffe0ef0f917921e6854fbde97252aa:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a9e209a7758f441a73f081d77fc12036-e3886ba3bbb20927d2359c215bbe95ad:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/726b5202287d50bf054280b6378283d3-a7faf1c4a419479169e8e379150905b6:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/985ba5b891167a96a77e50496a04d882-b05c000586e4bb6fcbf63a464b70214e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/82eaaa2e9193e726275e39eff00c41a9-4c130ad0683167971d0af9c990d9eb57:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cd971887b8a8768587abdbd0d1068d14-a77dd736cdd9b2dd15cded765ad4d4a1:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/954ac54af6d5bc6dca0988fb7d7614bf-a6cdec8d57e9b705b1226552c9980579:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_14_mk\temp_8.tif
# download successful !!!
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d19486e6e382b2b4ededd9d01ffb0ec9-bfa40949d09f634c71ec7affdc5045ec:getPixels
# Please wait ...
# File is not a zip file
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/65e4367096804e93a7c0382b7aa970e8-495d5f83e9bf0dd6f2fe757ac033e7be:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c71eb437e87cba4926bce5075396144c-254ce70d7d2c9f5db271088355a03e11:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/72e1a0bb448efeee30a0c9d12e169b1b-a21b6aadec463eb5d5037aa578becfd3:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a14e89aa5efd4105e41abbd0f1abe5bb-78e4ea0c9564a5b50dd6fdbd7dee982e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/296f6509c628342739d77dece202722c-cacfe9c5e7c754622351c1c2018b18a4:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/4652d0923ddf3d24e73b92533067b965-b3a1f20cd69cc7ffbd564b084554c77e:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8c77bab6acbab5972ced43195652e8f2-ef3c5eae23a8741ad92c77b490034441:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/12e40544af3949818d0246ef20c2e950-cd58f515e3f58644504d4e568cb7aca9:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/12e40544af3949818d0246ef20c2e950-cd58f515e3f58644504d4e568cb7aca9:getPixels (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_BAD_RECORD_MAC] sslv3 alert bad record mac (_ssl.c:2633)')))
# 下载不完全！！
# download successful !!!
# 分割成6份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d9a558a3780f5c80a3a0075edbd83208-8befd9be04d09f4d707d1bf857d5c30a:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_33_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/a4ee641fd598c0c3aa1f04e0abc54e3b-9501918ac10d754ba4f8cf0e2fd77a71:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_33_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9ef7d2be7f8c6c2b67d14568b286bc3b-9c9b9e829824c5748ed047bf58b69700:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_33_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b0b7c9c9dbb21d4d94a4e16c6d9e6b3f-ce6fb2d8fa78c912dcbeffcde80b126b:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_33_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3020e1b9b9a37ca7f57a68a8c8128593-efcef434856838f06aa17053347f75fe:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_33_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/0eea8d9e437eb64790813f6a39d7bd80-53d738456f0a97a940748a775003d6e7:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_33_mk\temp_5.tif
# download successful !!!
# 下载不完全！！
# download successful !!!
# 分割成36份, 开始下载:
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/cdcfb04350d17850d660c5643eafb117-56bb735ce0597d6ef8b2f31437b700ed:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8d5b869ebdfb6223d68585e937ce4a50-a253e32fb9589844d4c8937cc7cb5bb5:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6910f693f9673e77dbae0b8ae396ad04-0c029180c19b3fd3c5a8861587bee263:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/514b09e1126a892c1f185a1c632d19f0-10e618c5591ede808ec06c9574c00eaf:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/faf179edf7a1e22b45ff56d1bc71b6ab-62352eb0fa37036d6440ca37ba16334f:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/faf179edf7a1e22b45ff56d1bc71b6ab-62352eb0fa37036d6440ca37ba16334f:getPixels (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None)))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/c5bb711a7f599103c3858c84ad053a11-204e5708ed7059e3ffadba9eeb4ed70d:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7aa59f827d51f408153dbf59c9eaab50-e2b455bff1b19a05b3a228cf985052c5:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/62d421729b0eae7f5739d1b886940740-4067268d4002abc4f966c100376cc1bc:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/99875dbc27d94cefc8929087881e245b-e3681a30a118c027d83c96053c21d1f7:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/99875dbc27d94cefc8929087881e245b-e3681a30a118c027d83c96053c21d1f7:getPixels (Caused by ProxyError('Cannot connect to proxy.', RemoteDisconnected('Remote end closed connection without response')))
# 下载不完全！！
# download successful !!!
# 下载不完全！！
# download successful !!!
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f007df038018d4d94baea19b4557f246-9a279fc086404985d76952ca1c5cc443:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/7c30c57cccdff190090aaa13a92de7fa-f365a2e674702e7eca67bc0c89554f43:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/7c30c57cccdff190090aaa13a92de7fa-f365a2e674702e7eca67bc0c89554f43:getPixels (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_BAD_RECORD_MAC] sslv3 alert bad record mac (_ssl.c:2633)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d0ada204f2bf31e760239eff1bbf96ab-226f4850874e03eaa4aa4e8173834710:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3f77014016bdd5e1ec3e9dec27feed68-8cc066b24a00ba53fb852efd70de74da:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/25ff2a3fe484b2d19b6100632adc9fe8-3ad1a0b5502666c332e89711f84851c2:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/25ff2a3fe484b2d19b6100632adc9fe8-3ad1a0b5502666c332e89711f84851c2:getPixels (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/672a2c6e56db84e7808e23841434c5a4-55f4052f3777b4c7891f52a9097c064d:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/672a2c6e56db84e7808e23841434c5a4-55f4052f3777b4c7891f52a9097c064d:getPixels (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/db9a840b5c6ec7058645a28cbfbe3ce5-6519dabefef55f889f97b0e0c585b9ea:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/603fba13082dc0f3b2b42251e3dfb620-39d782ff46cfb30a8d94d5a9695afe6d:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/85c4e158a775c46aa8f8891005eb4cc9-ba15891b62297bda2bd609a9bdb8515a:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_8.tif
# 下载不完全！！
# download successful !!!
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/12e40544af3949818d0246ef20c2e950-2c4ddd23f2324b285a964192e2df6efe:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_8.tif
# download successful !!!
# 下载不完全！！
# download successful !!!
# 下载不完全！！
# download successful !!!
# 分割成36份, 开始下载:
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d983f6a8c1e31759d6edca0c8342631d-be1cc8ad5ec27c74e39ee9a7138fc80f:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8d82dafb3b083b462282e4f1b1eb81f1-5051ddc54a2215a253f9922a05af6d02:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/663817c4b1405ceccba126efada2d80d-f407b85bee022aab308fb55c3b48b765:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d1504a06ed12291c604f6fc9df8a19fe-7c69eb0faa66cfde9df4a2db259ff8b0:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/d9bd17ba7087d9cc25d308916248c260-c619c4fddef65361d2dc09ab6ff5733a:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/03dab7d3dda535683c91557bde8cc918-37a01802934737711c90063727cae62b:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f4b26e81eeb8e15ac0c65b93515a925f-0aa1f96deee9dfb29595437ba48659b6:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/23c6bc5a64e4b19b5d540e3190b9a81e-0469ed6a219651b4ba17268e9a0c63e9:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/99875dbc27d94cefc8929087881e245b-add3441a6cf40cc4c9cc84162fddfd3c:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_4_mk\temp_8.tif
# download successful !!!
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/99875dbc27d94cefc8929087881e245b-43065fdc766c8e55467a73ac614b7ec8:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_10_mk\temp_1_mk\temp_8.tif
# download successful !!!
# download successful !!!
# download successful !!!
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dad88753920d285f8687a2a1f68b73fd-71752d3614b661e569cbe28d5e492fe2:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/56db5d2cecf258bc85988eb9a124797c-e7a34deb3c01221c722643cba0ac19d3:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/452fcc57171e5e97fac171a63758014f-026124267e34051e948be8388c4cd052:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b5c5e7c2d60c0a5311d271fe86376662-e3aa52e79b804cb11e606b7e05021018:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/968911dc6c1f2475e14fe9fed9ffb762-189944c81a767dc2195c3e29577c428a:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/6cdee9628731e59c9e9d52e1d3d5fe06-08d7387474747c689fbb290efbc3dff1:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9a4b4230b6a3f018e37e4ade39a25997-3170d006c2606737d88a64421e6dc3c4:getPixels
# Please wait ...
# An error occurred while downloading.
# HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1alpha/projects/earthengine-legacy/thumbnails/9a4b4230b6a3f018e37e4ade39a25997-3170d006c2606737d88a64421e6dc3c4:getPixels (Caused by SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:1129)')))
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/9ab4dec8ab54e090ff79ec89b02529a8-1519f03497ef5b0290093ebf7049b87a:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/14fa3c739fa86f757baf1d41a8083e2a-1e4a197af0d887dd5b7cef6c54878735:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_8.tif
# 下载不完全！！
# download successful !!!
# 分割成9份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/03b84224b26a5a1280c2a85fc6a3a829-82f3f1a3f15e13538067af274eecbea2:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/dcba9f1d234395e53915c0b786efe3f3-87a070471a6306029e7a8da17acac20b:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8d1e3a7805949a24fc64d030a49a47d2-008242d8cc3cf62004f92d5ac71b762f:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_2.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/b27938d9d011c8ad57b2d3ba12166a3c-530b173ef45d6124d31e511ba6debeeb:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_3.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/5efbdc52c8f808106c4afd3a41fdc331-f6cf47fd60dfb3cde89e8b75a4e39a72:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_4.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/3ad7612a0c042626ff5479ced303b80d-8e7e5220e10e16dccc5514e03bd47a02:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_5.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/94c75f314533aaa26f271c464e80ca3f-ee9d695523df4e75e7424dc270c487b8:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_6.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8caabff970a37a7bead9d33de9634008-948cab52ded469bcf7c7bb4c3f158593:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_7.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/85c4e158a775c46aa8f8891005eb4cc9-b7a48fd02d88915fd89940fb6ab7fbc7:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_4_mk\temp_8.tif
# download successful !!!
# 分割成3份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/773d917175381aebf0e85751b0b890a3-8fb1602ae8a82f7138d0bf8db495d547:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_5_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/f124bd86c439862027014a9ac93cb3bd-c36e0c7850eb9204ab9aa4de9a006d06:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_5_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/33b29ac75d1677ec6c86b8ea2c4c8029-a05b69df8c115053f89b3e45e3c78f14:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_5_mk\temp_2.tif
# download successful !!!
# 下载不完全！！
# download successful !!!
# 下载不完全！！
# download successful !!!
# 下载不完全！！
# download successful !!!
# 分割成36份, 开始下载:
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# 分割成9份, 开始下载:
# 分割成3份, 开始下载:
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/87c3808fd8673f5c1169eef65fc82c71-08d506cacf1a30a8a7822c4e3fd307b6:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_6_mk\temp_0.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/8aaa2cf1a76327dba6611dcb58442c6e-6fb49c77dedb2faeece0980c9363fc14:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_6_mk\temp_1.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/thumbnails/2099a70cc41a3878d81373e28aa76e10-a570a68317dc3b06358cc39895c360c8:getPixels
# Please wait ...
# Data downloaded to C:\Users\树风\Desktop\下载数据\JX_DEM_90m_mk\temp_16_mk\temp_0_mk\temp_1_mk\temp_6_mk\temp_2.tif
# download successful !!!
# download successful !!!
# download successful !!!
# download successful !!!
# download successful !!!

# %%
#geemap.ee_export_image(dem_img, filename=f, scale=90, region=roi, file_per_band=False)   #将影像导出自本地文件夹，不分离波段
# Out:
# Generating URL ...
# An error occurred while downloading.
# Total request size (163627659 bytes) must be less than or equal to 33554432 bytes.
