# %%
import ee
import geemap
Map = geemap.Map(center=[40, -100], zoom=4)
Map
# Out:
# Map(center=[40, -100], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(T…
# There was an error creating Earth Engine Feature.
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     333   try:
# --> 334     return call.execute(num_retries=num_retries)
#     335   except googleapiclient.errors.HttpError as e:
#
# D:\anaconda\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# D:\anaconda\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps?fields=name&alt=json returned "Geometry.buffer: Can't buffer with a 0 error margin.". Details: "Geometry.buffer: Can't buffer with a 0 error margin.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# D:\anaconda\lib\site-packages\geemap\geemap.py in handle_draw(target, action, geo_json)
#     518                 self.user_rois = collection
# --> 519                 ee_draw_layer = ee_tile_layer(
#     520                     collection, {"color": "blue"}, "Drawn Features", False, 0.5
#
# D:\anaconda\lib\site-packages\geemap\geemap.py in ee_tile_layer(ee_object, vis_params, name, shown, opacity)
#    6384
# -> 6385     map_id_dict = ee.Image(image).getMapId(vis_params)
#    6386     tile_layer = ipyleaflet.TileLayer(
#
# D:\anaconda\lib\site-packages\ee\image.py in getMapId(self, vis_params)
#     129     request['image'] = vis_image
# --> 130     response = data.getMapId(request)
#     131     response['image'] = self
#
# D:\anaconda\lib\site-packages\ee\data.py in getMapId(params)
#     572   # request, which might be large.
# --> 573   result = _execute_cloud_call(
#     574       _get_cloud_api_resource().projects().maps().create(
#
# D:\anaconda\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     335   except googleapiclient.errors.HttpError as e:
# --> 336     raise _translate_cloud_exception(e)
#     337
#
# EEException: Geometry.buffer: Can't buffer with a 0 error margin.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\geemap\geemap.py in handle_draw(target, action, geo_json)
#     539                 self.roi_end = False
#     540                 print("There was an error creating Earth Engine Feature.")
# --> 541                 raise Exception(e)
#     542
#     543         draw_control.on_draw(handle_draw)
#
# Exception: Geometry.buffer: Can't buffer with a 0 error margin.
# There was an error creating Earth Engine Feature.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\anaconda\lib\site-packages\geemap\geemap.py in handle_draw(target, action, geo_json)
#     527                 else:
# --> 528                     self.substitute_layer(self.draw_layer, ee_draw_layer)
#     529                     self.draw_layer = ee_draw_layer
#
# D:\anaconda\lib\site-packages\ipyleaflet\leaflet.py in substitute_layer(self, old, new)
#    2158             new = basemap_to_tiles(new)
# -> 2159         if old.model_id not in self._layer_ids:
#    2160             raise LayerException('Could not substitute layer: layer not on map.')
#
# AttributeError: 'NoneType' object has no attribute 'model_id'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# D:\anaconda\lib\site-packages\geemap\geemap.py in handle_draw(target, action, geo_json)
#     539                 self.roi_end = False
#     540                 print("There was an error creating Earth Engine Feature.")
# --> 541                 raise Exception(e)
#     542
#     543         draw_control.on_draw(handle_draw)
#
# Exception: 'NoneType' object has no attribute 'model_id'

# %%
naip_url = 'https://services.nationalmap.gov/arcgis/services/USGSNAIPImagery/ImageServer/WMSServer?'
Map.add_wms_layer(url=naip_url, layers='0', name='NAIP Imagery', format='image/png', shown=True)

# %%
collection = ee.ImageCollection("USGS/NLCD")
print(collection.aggregate_array('system:id').getInfo())
# Out:
# {'type': 'ImageCollection', 'bands': [], 'id': 'USGS/NLCD', 'version': 1633264253212588, 'properties': {'system:visualization_0_min': '0.0', 'type_name': 'ImageCollection', 'keywords': ['blm', 'landcover', 'mrlc', 'nlcd', 'shrub', 'shrubland', 'usgs'], 'thumb': 'https://mw1.google.com/ges/dd/images/USGS_NLCD_thumb.png', 'description': '<p>NLCD (the National Land Cover Database) is a 30-m Landsat-based land cover\ndatabase spanning 8 epochs (1992, 2001, 2004, 2006, 2008, 2011, 2013 and 2016).\n1992 data are primarily based on unsupervised classification of Landsat data,\nwhile the rest of the images rely on the imperviousness data layer for the\nurban classes and on a decision-tree classification for the rest. The 1992\nimage is not directly comparable to any later editions of NLCD.</p><p>This dataset has one image for the continental US for each of the\neight epochs, plus separate images for Alaska, Hawaii, and Puerto Rico in 2001 and 2011.\n(They could not be merged in due to having a different projection from the continental US\nimages.)</p><p>Note that the impervious layers and tree cover layers for Alaska 2011\nonly have data for parts of Alaska.  For the impervious layer, only the\nparts of Kenai Peninsula Borough and Anchorage Municipality are available.\nTree cover is only available on a strip along the coast from the southern\ntip of the Alaskan Panhandle up through the Kenai Peninsula, plus Kodiak\nIsland.</p><p>NLCD 2016 Shrub Component products characterize the percentage of each\n30-meter pixel in the Western United States covered by shrub, herbaceous,\nbare ground, litter, sagebrush, big sagebrush and annual herbaceous, along\nwith estimating shrub height and sagebrush height. These products have\nbeen produced by USGS in collaboration with the Bureau of Land Management.</p><p>NLCD products are created by the Multi-Resolution Land Characteristics\n(MRLC) Consortium, a partnership of federal agencies led by the\nU.S. Geological Survey.</p><p><b>Resolution</b><br>30 meters\n</p><p><b>Bands</b><table class="eecat"><tr><th scope="col">Name</th><th scope="col">Description</th></tr><tr><td>landcover</td><td><p>All images except NCLD2011_HI and NLCD2011_PR include the landcover classification scheme described in the <a href="https://www.mrlc.gov/data/legends/national-land-cover-database-2016-nlcd2016-legend">2016 Product Legend</a>. The legends are also available as metadata on each image. The classes in the 2016 product legend are given below.</p></td></tr><tr><td>impervious</td><td><p>Percent of the pixel covered by developed impervious surface. Included in images NLCD2001, NLCD2001_AK, NLCD2001_HI, NLCD2001_PR, NLCD2006, NLCD2011, NLCD2011_AK, and NLCD2016.</p></td></tr><tr><td>impervious_descriptor</td><td><p>Defines which impervious layer pixels are roads and provides the best fit description for impervious pixels that are not roads. Included in images NLCD2001, NLCD2006, NLCD2011, and NLCD2016.</p></td></tr><tr><td>percent_tree_cover</td><td><p>Percent of the pixel that&#39;s covered by tree canopy. No masking of obvious non-tree areas is performed for this product. Included in images NLCD2011, NLCD2011_AK, NLCD2011_HI, NLCD2011_PR, and NLCD2016.</p></td></tr><tr><td>percent_tree_error</td><td><p>Standard error for the model as a percentage from 0 to 45. The higher the value, the greater the model uncertainty in estimating the canopy value for that cell. Included in NLCD2011, NLCD2011_AK, NLCD2011_HI, and NLCD2011_PR.</p></td></tr><tr><td>shrubland_annual_herbaceous</td><td><p>The annual only grass and forb proportion in each in 30m pixel. Included in NLCD2016.</p></td></tr><tr><td>shrubland_bare_ground</td><td><p>The bare ground proportion in each 30m pixel. Included in NLCD2016.</p></td></tr><tr><td>shrubland_big_sagebrush</td><td><p>The proportion of big sagebrush canopy in each 30m pixel. Included in NLCD2016.</p></td></tr><tr><td>shrubland_herbaceous</td><td><p>The annual and perennial grass and forb proportio ...
# ['USGS/NLCD/NLCD1992', 'USGS/NLCD/NLCD2001', 'USGS/NLCD/NLCD2001_AK', 'USGS/NLCD/NLCD2001_HI', 'USGS/NLCD/NLCD2001_PR', 'USGS/NLCD/NLCD2004', 'USGS/NLCD/NLCD2006', 'USGS/NLCD/NLCD2008', 'USGS/NLCD/NLCD2011', 'USGS/NLCD/NLCD2011_AK', 'USGS/NLCD/NLCD2011_HI', 'USGS/NLCD/NLCD2011_PR', 'USGS/NLCD/NLCD2013', 'USGS/NLCD/NLCD2016']

# %%
# Add Earth Engine dataset
image = ee.Image('USGS/SRTMGL1_003')

# Set visualization parameters.
vis_params = {
  'min': 0,
  'max': 4000,
  'palette': ['006633', 'E5FFCC', '662A00', 'D8D8D8', 'F5F5F5']}

# Add Earth Engine DEM to map
Map.addLayer(image, vis_params, 'SRTM DEM')

states = ee.FeatureCollection("TIGER/2018/States")
Map.addLayer(states, {}, 'US States')

# %%
Map.draw_features
# Out:
# []

# %%
Map.draw_last_feature

# %%
roi = ee.FeatureCollection(Map.draw_features)
selected_states = states.filterBounds(roi)
Map.addLayer(selected_states, {}, "Selected states")

# %%
clipped_image = image.clip(selected_states)
Map.addLayer(clipped_image, vis_params, 'Clipped image')
